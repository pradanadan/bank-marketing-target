# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("bank_additional.csv", sep=';')

# %%
data.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0         -1.8          92.893          -46.2      1.313       5099.1  no
# 1          1.1          93.994          -36.4      4.855       5191.0  no
# 2          1.4          94.465          -41.8      4.962       5228.1  no
# 3          1.4          94.465          -41.8      4.959       5228.1  no
# 4         -0.1          93.200          -42.0      4.191       5195.8  no
#
# [5 rows x 21 columns]

# %%
data = data.drop(["contact", "month", "day_of_week"], axis=1)
data.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#    duration  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0       487         2    999         0  nonexistent          -1.8
# 1       346         4    999         0  nonexistent           1.1
# 2       227         1    999         0  nonexistent           1.4
# 3        17         3    999         0  nonexistent           1.4
# 4        58         1    999         0  nonexistent          -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.313       5099.1  no
# 1          93.994          -36.4      4.855       5191.0  no
# 2          94.465          -41.8      4.962       5228.1  no
# 3          94.465          -41.8      4.959       5228.1  no
# 4          93.200          -42.0      4.191       5195.8  no

# %%
data.nunique()
# Out:
# age                67
# job                12
# marital             4
# education           8
# default             3
# housing             3
# loan                3
# duration          828
# campaign           25
# pdays              21
# previous            7
# poutcome            3
# emp.var.rate       10
# cons.price.idx     26
# cons.conf.idx      26
# euribor3m         234
# nr.employed        11
# y                   2
# dtype: int64

# %%
data["y"].replace(('yes', 'no'), (1, 0), inplace=True)
data.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#    duration  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0       487         2    999         0  nonexistent          -1.8
# 1       346         4    999         0  nonexistent           1.1
# 2       227         1    999         0  nonexistent           1.4
# 3        17         3    999         0  nonexistent           1.4
# 4        58         1    999         0  nonexistent          -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          92.893          -46.2      1.313       5099.1  0
# 1          93.994          -36.4      4.855       5191.0  0
# 2          94.465          -41.8      4.962       5228.1  0
# 3          94.465          -41.8      4.959       5228.1  0
# 4          93.200          -42.0      4.191       5195.8  0

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed  \
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# min       -3.400000       92.201000     -50.800000     0.635000  4963.600000
# 25%       -1.800000       93.075000     -42.700000     1.334000  5099.100000
# 50%        1.100000       93.749000     -41.800000     4.857000  5191.000000
# 75%        1.400000       93.994000     -36.400000     4.961000  5228.100000
# max        1.400000       94.767000     -26.900000     5.045000  5228.100000
#
#                  y
# count  4119.000000
# mean      0.109493
# std       0.312294
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
data.corr()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.041299 -0.014169 -0.043425  0.050931
# duration        0.041299  1.000000 -0.085348 -0.046998  0.025724
# campaign       -0.014169 -0.085348  1.000000  0.058742 -0.091490
# pdays          -0.043425 -0.046998  0.058742  1.000000 -0.587941
# previous        0.050931  0.025724 -0.091490 -0.587941  1.000000
# emp.var.rate   -0.019192 -0.028848  0.176079  0.270684 -0.415238
# cons.price.idx -0.000482  0.016672  0.145021  0.058472 -0.164922
# cons.conf.idx   0.098135 -0.034745  0.007882 -0.092090 -0.051420
# euribor3m      -0.015033 -0.032329  0.159435  0.301478 -0.458851
# nr.employed    -0.041936 -0.044218  0.161037  0.381983 -0.514853
# y               0.060374  0.418565 -0.076091 -0.332012  0.255697
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.019192       -0.000482       0.098135  -0.015033
# duration           -0.028848        0.016672      -0.034745  -0.032329
# campaign            0.176079        0.145021       0.007882   0.159435
# pdays               0.270684        0.058472      -0.092090   0.301478
# previous           -0.415238       -0.164922      -0.051420  -0.458851
# emp.var.rate        1.000000        0.755155       0.195022   0.970308
# cons.price.idx      0.755155        1.000000       0.045835   0.657159
# cons.conf.idx       0.195022        0.045835       1.000000   0.276595
# euribor3m           0.970308        0.657159       0.276595   1.000000
# nr.employed         0.897173        0.472560       0.107054   0.942589
# y                  -0.283216       -0.098326       0.054393  -0.298565
#
#                 nr.employed         y
# age               -0.041936  0.060374
# duration          -0.044218  0.418565
# campaign           0.161037 -0.076091
# pdays              0.381983 -0.332012
# previous          -0.514853  0.255697
# emp.var.rate       0.897173 -0.283216
# cons.price.idx     0.472560 -0.098326
# cons.conf.idx      0.107054  0.054393
# euribor3m          0.942589 -0.298565
# nr.employed        1.000000 -0.349241
# y                 -0.349241  1.000000

# %%
sns.relplot(data=data, x='duration', y='previous', hue='y', alpha=0.6)

# %%
# duration affect responses, higher campaign duration has a tendency to get 'yes' response.
# previous campaign reduces duration needed for customer to give 'yes' response.

# %%
sns.relplot(data=data, x='duration', y='pdays', hue='y', alpha=0.6)

# %%
# customers who get campaign in a few previous day have a tendency to give 'yes' response.

# %%
sns.relplot(data=data, x='previous', y='pdays', hue='y', alpha=0.6)

# %%
data.hist(column='job', by='y', bins=23)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000023931FD4550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023931FFAA00>],
#       dtype=object)

# %%
data.hist(column='marital', by='y', bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000023931F49820>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000239321B3B50>],
#       dtype=object)

# %%
data.hist(column='education', by='y', bins=23)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000023932244E50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002393226EC70>],
#       dtype=object)

# %%
data.hist(column='default', by='y', bins=5)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000023932360250>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002393238BE20>],
#       dtype=object)

# %%
data.hist(column='housing', by='y', bins=5)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000239323F9D60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023932433A90>],
#       dtype=object)

# %%
data.hist(column='loan', by='y', bins=5)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002393246AE50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023931EFE100>],
#       dtype=object)

# %%
data.boxplot(column='age', by='y')
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# Analyze how social index affect rensponse

# %%
data.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#    duration  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0       487         2    999         0  nonexistent          -1.8
# 1       346         4    999         0  nonexistent           1.1
# 2       227         1    999         0  nonexistent           1.4
# 3        17         3    999         0  nonexistent           1.4
# 4        58         1    999         0  nonexistent          -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          92.893          -46.2      1.313       5099.1  0
# 1          93.994          -36.4      4.855       5191.0  0
# 2          94.465          -41.8      4.962       5228.1  0
# 3          94.465          -41.8      4.959       5228.1  0
# 4          93.200          -42.0      4.191       5195.8  0

# %%
data.corr()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.041299 -0.014169 -0.043425  0.050931
# duration        0.041299  1.000000 -0.085348 -0.046998  0.025724
# campaign       -0.014169 -0.085348  1.000000  0.058742 -0.091490
# pdays          -0.043425 -0.046998  0.058742  1.000000 -0.587941
# previous        0.050931  0.025724 -0.091490 -0.587941  1.000000
# emp.var.rate   -0.019192 -0.028848  0.176079  0.270684 -0.415238
# cons.price.idx -0.000482  0.016672  0.145021  0.058472 -0.164922
# cons.conf.idx   0.098135 -0.034745  0.007882 -0.092090 -0.051420
# euribor3m      -0.015033 -0.032329  0.159435  0.301478 -0.458851
# nr.employed    -0.041936 -0.044218  0.161037  0.381983 -0.514853
# y               0.060374  0.418565 -0.076091 -0.332012  0.255697
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.019192       -0.000482       0.098135  -0.015033
# duration           -0.028848        0.016672      -0.034745  -0.032329
# campaign            0.176079        0.145021       0.007882   0.159435
# pdays               0.270684        0.058472      -0.092090   0.301478
# previous           -0.415238       -0.164922      -0.051420  -0.458851
# emp.var.rate        1.000000        0.755155       0.195022   0.970308
# cons.price.idx      0.755155        1.000000       0.045835   0.657159
# cons.conf.idx       0.195022        0.045835       1.000000   0.276595
# euribor3m           0.970308        0.657159       0.276595   1.000000
# nr.employed         0.897173        0.472560       0.107054   0.942589
# y                  -0.283216       -0.098326       0.054393  -0.298565
#
#                 nr.employed         y
# age               -0.041936  0.060374
# duration          -0.044218  0.418565
# campaign           0.161037 -0.076091
# pdays              0.381983 -0.332012
# previous          -0.514853  0.255697
# emp.var.rate       0.897173 -0.283216
# cons.price.idx     0.472560 -0.098326
# cons.conf.idx      0.107054  0.054393
# euribor3m          0.942589 -0.298565
# nr.employed        1.000000 -0.349241
# y                 -0.349241  1.000000

# %%
sns.relplot(x='emp.var.rate', y='cons.price.idx', hue='y', alpha=0.6, data=data)

# %%
sns.relplot(x='cons.conf.idx', y='euribor3m', hue='y', alpha=0.6, data=data)

# %%
sns.relplot(x='nr.employed', y='emp.var.rate', hue='y', alpha=0.6, data=data)

# %%
# Social index data will be droped since have a low effect on renponse

# %%
data = data.drop(['emp.var.rate','cons.price.idx','cons.conf.idx','euribor3m','nr.employed'], axis=1)
data.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#    duration  campaign  pdays  previous     poutcome  y
# 0       487         2    999         0  nonexistent  0
# 1       346         4    999         0  nonexistent  0
# 2       227         1    999         0  nonexistent  0
# 3        17         3    999         0  nonexistent  0
# 4        58         1    999         0  nonexistent  0

# %%
data.to_csv('cleaned_bank_campaign.csv')
